# %% [markdown]
# Connected to m4d (Python 3.11.6)

# %%
import numpy as np
import pandas as pd

# %%
base_dir = "/u/kroma/m4d/"
participant_file = base_dir + "data/ds005106-download/participants.tsv"

# %%
part_df = pd.read_csv(participant_file, sep="\t")

# %%
part_df
# Out:
#    #participant_id  age_months sex  blockscompleted  exclude  \
# 0          sub-001       5.000   M              5.0        0
# 1          sub-002      11.000   M              6.5        0
# 2          sub-003       5.600   F              1.5        1
# 3          sub-004      11.500   M              2.0        1
# 4          sub-005      11.500   F              6.0        0
# 5          sub-007       6.000   M              7.0        0
# 6          sub-008      11.200   F              5.0        0
# 7          sub-009       5.870   M              4.5        0
# 8          sub-011       6.200   F              6.0        0
# 9          sub-012       6.750   M              3.0        1
# 10         sub-013       7.800   M              4.0        0
# 11         sub-014       5.000   F              5.0        0
# 12         sub-015       5.100   F              6.5        0
# 13         sub-016       7.500   M              3.5        1
# ...

# %%
included_subs = part_df[part_df.exlude==0]["#participant_id"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-bc7db542c4a7> in ?()
# ----> 1 included_subs = part_df[part_df.exlude==0]["#participant_id"]
#
# ~/conda-envs/m4d/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'exlude'

# %%
included_subs = part_df[part_df.exclude==0]["#participant_id"]

# %%
included_subs
# Out:
# 0     sub-001
# 1     sub-002
# 4     sub-005
# 5     sub-007
# 6     sub-008
# 7     sub-009
# 8     sub-011
# 10    sub-013
# 11    sub-014
# 12    sub-015
# 14    sub-017
# 15    sub-018
# 17    sub-020
# 18    sub-021
# 19    sub-022
# 20    sub-023
# 21    sub-024
# 22    sub-025
# 23    sub-026
# 24    sub-027
# 25    sub-028
# 26    sub-030
# 29    sub-035
# 30    sub-036
# 31    sub-037
# 32    sub-039
# 33    sub-040
# 34    sub-042
# 35    sub-043
# 36    sub-044
# 37    sub-045
# 38    sub-046
# 39    sub-048
# 40    sub-049
# Name: #participant_id, dtype: object

# %%
included_subs = part_df[part_df.exclude==0]["#participant_id"].reset_index()

# %%
included_subs = part_df[part_df.exclude==0]["#participant_id"].reset_index()

# %%
included_subs = part_df[part_df.exclude==0]["#participant_id"].reset_index()
